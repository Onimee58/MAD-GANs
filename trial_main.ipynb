# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
% cd '/content/drive/MyDrive/prof ttu/MAD-GANs-master'
# Out:
# /content/drive/MyDrive/prof ttu/MAD-GANs-master

# %%
! pip install scipy==1.2
! pip install -U scikit-learn matplotlib
% tensorflow_version 1.x

# %%
! python AD.py --settings_file kdd99_test
# Out:
# Streaming output truncated to the last 5000 lines.
# pciBusID: 0000:00:04.0
# 2022-04-01 15:09:06.081195: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.1
# 2022-04-01 15:09:06.081239: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcublas.so.10
# 2022-04-01 15:09:06.081318: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcufft.so.10
# 2022-04-01 15:09:06.081364: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcurand.so.10
# 2022-04-01 15:09:06.081407: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusolver.so.10
# 2022-04-01 15:09:06.081447: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusparse.so.10
# ...
